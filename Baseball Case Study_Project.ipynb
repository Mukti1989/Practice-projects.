# %%
# Import All libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %%
df=pd.read_csv('baseball.csv')
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
print(df.shape)
# Out:
# (30, 17)

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull().sum().to_frame())
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
# Change Column Name
df.rename({'W':'Win', 'R':'Runs','AB':'At_BAT','H':'Hits','2B': 'Doubles','3B':'Triples','HR': 'Homeruns','BB': 'Walks','SO': 'Strikeouts','SB': 'Stolen_Bases','RA': 'Runs_Allowed','ER': 'Earned_Runs','ERA': 'Earned_Run_Average','CG': 'Complete_Game','SV': 'Saves','SV':'Save','E': 'Errors'}, axis=1, inplace=True)
df
# Out:
#     Win  Runs  At_BAT  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0    95   724    5575  1497      300       42       139    383         973
# 1    83   696    5467  1349      277       44       156    439        1264
# 2    81   669    5439  1395      303       29       141    533        1157
# 3    76   622    5533  1381      260       27       136    404        1231
# 4    74   689    5605  1515      289       49       151    455        1259
# 5    93   891    5509  1480      308       17       232    570        1151
# 6    87   764    5567  1397      272       19       212    554        1227
# 7    81   713    5485  1370      246       20       217    418        1331
# 8    80   644    5485  1383      278       32       167    436        1310
# 9    78   748    5640  1495      294       33       161    478        1148
# 10   88   751    5511  1419      279       32       172    503        1233
# ...

# %%
df.head()
# Out:
#    Win  Runs  At_BAT  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0   95   724    5575  1497      300       42       139    383         973
# 1   83   696    5467  1349      277       44       156    439        1264
# 2   81   669    5439  1395      303       29       141    533        1157
# 3   76   622    5533  1381      260       27       136    404        1231
# 4   74   689    5605  1515      289       49       151    455        1259
#
#    Stolen_Bases  Runs_Allowed  Earned_Runs  Earned_Run_Average  Complete_Game  \
# 0           104           641          601                3.73              2
# 1            70           700          653                4.07              2
# 2            86           640          584                3.67             11
# 3            68           701          643                3.98              7
# 4            83           803          746                4.64              7
#
#    SHO  Save  Errors
# 0    8    56      88
# ...

# %%
df.columns
# Out:
# Index(['Win', 'Runs', 'At_BAT', 'Hits', 'Doubles', 'Triples', 'Homeruns',
#        'Walks', 'Strikeouts', 'Stolen_Bases', 'Runs_Allowed', 'Earned_Runs',
#        'Earned_Run_Average', 'Complete_Game', 'SHO', 'Save', 'Errors'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Win        Runs       At_BAT         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen_Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %% [markdown]
# # EDA

# %%
sns.scatterplot(x='At_BAT', y='Win', data=df)
# Out:
# <AxesSubplot:xlabel='At_BAT', ylabel='Win'>

# %%
sns.scatterplot(x='Hits', y='Win', data=df)
# Out:
# <AxesSubplot:xlabel='Hits', ylabel='Win'>

# %%
sns.scatterplot(x='Doubles', y='Win', data=df)
# Out:
# <AxesSubplot:xlabel='Doubles', ylabel='Win'>

# %%
sns.scatterplot(x='Triples', y='Win', data=df)
# Out:
# <AxesSubplot:xlabel='Triples', ylabel='Win'>

# %%
sns.scatterplot(x='Homeruns', y='Win', data=df)
# Out:
# <AxesSubplot:xlabel='Homeruns', ylabel='Win'>

# %%
sns.scatterplot(x='Walks', y='Win', data=df)
# Out:
# <AxesSubplot:xlabel='Walks', ylabel='Win'>

# %%
sns.scatterplot(x='Earned_Run_Average', y='Win', data=df)
# Out:
# <AxesSubplot:xlabel='Earned_Run_Average', ylabel='Win'>

# %%
df.corr()
# Out:
#                          Win      Runs    At_BAT      Hits   Doubles  \
# Win                 1.000000  0.430751 -0.087947  0.037612  0.427797
# Runs                0.430751  1.000000  0.319464  0.482856  0.560084
# At_BAT             -0.087947  0.319464  1.000000  0.739122  0.453370
# Hits                0.037612  0.482856  0.739122  1.000000  0.566847
# Doubles             0.427797  0.560084  0.453370  0.566847  1.000000
# Triples            -0.251118 -0.070072  0.435422  0.478694  0.220490
# Homeruns            0.307407  0.671283 -0.066983 -0.090855  0.056292
# Walks               0.484342  0.402452 -0.136414 -0.118281  0.302700
# Strikeouts          0.111850 -0.054726 -0.106022 -0.398830 -0.150752
# Stolen_Bases       -0.157234  0.081367  0.372618  0.413444  0.195027
# Runs_Allowed       -0.812952 -0.041623  0.316010  0.224324 -0.218160
# Earned_Runs        -0.809435 -0.041245  0.309686  0.252489 -0.235531
# Earned_Run_Average -0.819600 -0.049281  0.255551  0.231172 -0.254854
# ...

# %%
df.corr()["Win"].sort_values()
# Out:
# Earned_Run_Average   -0.819600
# Runs_Allowed         -0.812952
# Earned_Runs          -0.809435
# Triples              -0.251118
# Stolen_Bases         -0.157234
# Errors               -0.089485
# At_BAT               -0.087947
# Hits                  0.037612
# Complete_Game         0.080533
# Strikeouts            0.111850
# Homeruns              0.307407
# Doubles               0.427797
# Runs                  0.430751
# SHO                   0.471805
# Walks                 0.484342
# Save                  0.666530
# win_bins              0.917736
# Win                   1.000000
# Name: Win, dtype: float64

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidth=0.5,linecolor='black', fmt= '.2f')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#               Win        Runs       At_BAT         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen_Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True, fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summery")
plt.show()

# %% [markdown]
# # Outliers Checking

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green', orient='v')
    plt.tight_layout()

# %%
# Skewness
df.skew()
# Out:
# Win                   0.047089
# Runs                  1.200786
# At_BAT                0.183437
# Hits                  0.670254
# Doubles              -0.230650
# Triples               0.129502
# Homeruns              0.516441
# Walks                 0.158498
# Strikeouts           -0.156065
# Stolen_Bases          0.479893
# Runs_Allowed          0.045734
# Earned_Runs           0.058710
# Earned_Run_Average    0.053331
# Complete_Game         0.736845
# SHO                   0.565790
# Save                  0.657524
# Errors                0.890132
# win_bins             -0.036797
# dtype: float64

# %%
# Normal Distribution Curve
sns.distplot(df['Win'])
# Out:
# <AxesSubplot:xlabel='Win', ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score
